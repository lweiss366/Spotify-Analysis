# %% [markdown]
# # Spotify Data Exploration

# %% [markdown]
# ### This is a data exploration of Spotify song data from the year 1921 to the present. I used two datasets that I got from kaggle.
# #### source: https://www.kaggle.com/datasets/conorvaneden/best-songs-on-spotify-for-every-year-2000-2023
# #### source: https://www.kaggle.com/datasets/ektanegi/spotifydata-19212020
# ### by: Luke Weiss

# %%
import pandas as pd

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

from sklearn.linear_model import LinearRegression,  LogisticRegression, Ridge, Lasso
import sklearn
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import PolynomialFeatures, StandardScaler, MinMaxScaler
from sklearn.pipeline import Pipeline
from sklearn.cluster import KMeans, AffinityPropagation
from sklearn.tree import DecisionTreeRegressor, DecisionTreeClassifier
from sklearn.metrics import mean_absolute_error, accuracy_score, r2_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.decomposition import PCA

import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

import zipfile

import warnings
warnings.filterwarnings('ignore')

import copy

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
# Out:
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ## Preprocessing of data:

# %%
top100_2000 = pd.read_csv("spotify.csv", delimiter = ";")
zf2 = zipfile.ZipFile("spotify_data.csv.zip")
df2 = pd.read_csv(zf2.open('data.csv'))

# %%
df2.head()
# Out:
#    valence  year  acousticness  \
# 0   0.0594  1921         0.982
# 1   0.9630  1921         0.732
# 2   0.0394  1921         0.961
# 3   0.1650  1921         0.967
# 4   0.2530  1921         0.957
#
#                                              artists  danceability  \
# 0  ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                     ['Dennis Day']         0.819
# 2  ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                   ['Frank Parker']         0.275
# 4                                     ['Phil Regan']         0.418
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       831667   0.211         0  4BJqT0PrAfrxzMOxytFOIz          0.878000
# 1       180533   0.341         0  7xPhfUan2yNtyFG0cUWkt8          0.000000
# 2       500062   0.166         0  1o6I8BglA6ylDMrIELygv1          0.913000
# 3       210000   0.309         0  3ftBPsC5vPBKxYSee08FDH          0.000028
# 4       166693   0.193         0  4d6HGyGT8e121BsdKmw9v6          0.000002
#
#    key  liveness  loudness  mode  \
# 0   10     0.665   -20.096     1
# 1    7     0.160   -12.441     1
# 2    3     0.101   -14.850     1
# 3    5     0.381    -9.316     1
# 4    3     0.229   -10.096     1
#
#                                                 name  popularity release_date  \
# 0  Piano Concerto No. 3 in D Minor, Op. 30: III. ...           4         1921
# 1                            Clancy Lowered the Boom           5         1921
# 2                                          Gati Bali           5         1921
# 3                                          Danny Boy           3         1921
# 4                        When Irish Eyes Are Smiling           2         1921
#
#    speechiness    tempo
# 0       0.0366   80.954
# 1       0.4150   60.936
# 2       0.0339  110.339
# 3       0.0354  100.109
# 4       0.0380  101.665

# %%
top100_2000.head()
# Out:
#                                     title          artist         top genre  \
# 0                                 Flowers     Miley Cyrus               pop
# 1                       Cupid - Twin Ver.     FIFTY FIFTY  k-pop girl group
# 2                                    BESO         ROSALÍA               pop
# 3                      Boy's a liar Pt. 2  PinkPantheress       bronx drill
# 4  Creepin' (with The Weeknd & 21 Savage)    Metro Boomin               rap
#
#    year  bpm  energy  danceability   dB  liveness  valence  duration  \
# 0  2023  118      68             71  -4         3       65       200
# 1  2023  120      59             78  -8        35       73       174
# 2  2023   95      64             77  -7        17       53       195
# 3  2023  133      81             70  -8        25       86       131
# 4  2022   98      62             72  -6         8       17       222
#
#    acousticness  speechiness   popularity
# 0             6             7          98
# 1            44             3          97
# 2            74            14          96
# 3            25             5          96
# 4            42             5          96

# %%
print(top100_2000.shape)
print(df2.shape)
# Out:
# (2385, 14)
# (170653, 19)

# %%
# I want to add total artist streams as a column to take into account. This is because more popular artists are going to be more likely to have more popular songs.
#First I am going to parse the first artists name from each row in the df.
artist_list = list()
for artist in df2["artists"]:
    current_artist = artist
    for ch in ["[", "]", "'"]:
        current_artist = current_artist.replace(ch, "")
        
    current_artist = current_artist.split(",")
    artist_list.append(current_artist[0])
    
df2["Top Artist"] = artist_list

# %%
# Then I am going to get a dict matching each artist name to the total number of streams they have by extracting it from a csv file I got on kaggle
# source: https://www.kaggle.com/datasets/adnananam/spotify-artist-stats

artist_data = pd.read_csv("spotify_artist_data.csv")
artist_data = artist_data[["Artist Name", "Lead Streams"]]
artist_streams = artist_data.set_index('Artist Name').to_dict()['Lead Streams']
artist_streams.pop("Artist")
for artist in artist_streams:
    curr_streams = artist_streams[artist]
    artist_streams[artist] = int(curr_streams.replace(",", ""))
    
artist_streams
# Out:
# {'Drake': 50162292808,
#  'Bad Bunny': 44369032140,
#  'Ed Sheeran': 38153682361,
#  'The Weeknd': 34767779741,
#  'Taylor Swift': 32596728109,
#  'Justin Bieber': 32465998885,
#  'Ariana Grande': 32287682040,
#  'Eminem': 30431861291,
#  'Post Malone': 29832277109,
#  'BTS': 28533458128,
#  'J Balvin': 25892190469,
#  'Kanye West': 25535119184,
#  'Billie Eilish': 23684986780,
#  'Juice WRLD': 23114066243,
#  'Coldplay': 22214835214,
#  'Dua Lipa': 22186290470,
#  'Imagine Dragons': 21812218476,
#  'XXXTENTACION': 21726799289,
#  'Ozuna': 21119272574,
#  'Khalid': 20973735166,
#  'Rihanna': 20761226681,
#  'Travis Scott': 20566427073,
#  'Maroon 5': 19952566778,
#  'David Guetta': 19104897589,
#  'Shawn Mendes': 18964777185,
#  'Bruno Mars': 18201285113,
#  'Daddy Yankee': 18075604863,
#  'Calvin Harris': 17820311936,
#  'Kendrick Lamar': 17650726013,
#  'Sam Smith': 16883863013,
#  'Queen': 16557204478,
#  'Beyoncé': 15593114022,
#  'Adele': 15561219687,
#  'Future': 15552849123,
#  'One Direction': 15499795436,
#  'The Chainsmokers': 15484677966,
#  'Chris Brown': 15440015429,
#  'Lady Gaga': 14897662581,
#  'J. Cole': 14849857590,
#  'Nicki Minaj': 14744100678,
#  'Anuel AA': 14364736608,
#  'Halsey': 14151726087,
#  'The Beatles': 14001404418,
#  'Selena Gomez': 13905383000,
#  'Sia': 13601270394,
#  'Maluma': 13551469480,
#  'Harry Styles': 13347420670,
#  'Marshmello': 13049327287,
#  'Lil Uzi Vert': 12985704210,
#  'Linkin Park': 12970759855,
#  'Twenty One Pilots': 12949146668,
#  'Rauw Alejandro': 12914088970,
#  'Katy Perry': 12631477879,
#  'Kygo': 12519097847,
#  'Avicii': 12484875427,
#  'Lana Del Rey': 12457976768,
#  'Farruko': 11983825654,
#  'Doja Cat': 11973361879,
#  'Camila Cabello': 11822254851,
#  'Jason Derulo': 11262694386,
#  'Arctic Monkeys': 11249748739,
#  'KAROL G': 11177377040,
#  'Red Hot Chili Peppers': 11005993478,
#  'Shakira': 10782631210,
#  'Demi Lovato': 10668611459,
#  'Miley Cyrus': 9940559934,
#  'OneRepublic': 9926540057,
#  'Nicky Jam': 9861155500,
#  'Michael Jackson': 9754680636,
#  'Lil Baby': 9670090585,
#  'Myke Towers': 9667486409,
#  'Charlie Puth': 9570632839,
#  'Pitbull': 9426002918,
#  'Martin Garrix': 9390213325,
#  'Sebastian Yatra': 9365402828,
#  'DaBaby': 9326324913,
#  '21 Savage': 9289820129,
#  'Mac Miller': 9187372325,
#  'Panic! At The Disco': 9107446450,
#  'Pop Smoke': 9097323859,
#  'Cardi B': 9066363643,
#  'Sech': 9011436885,
#  'Lil Wayne': 8970128688,
#  'Young Thug': 8956248071,
#  'Olivia Rodrigo': 8954631138,
#  'Metallica': 8890283866,
#  'G-Eazy': 8847885490,
#  'Ellie Goulding': 8826849897,
#  'Lil Nas X': 8778149366,
#  'Major Lazer': 8758754488,
#  'Alan Walker': 8727932813,
#  'Wiz Khalifa': 8695422254,
#  'Lil Peep': 8691721490,
#  'Diplo': 8496096848,
#  'Fall Out Boy': 8451431705,
#  'Elton John': 8437442330,
#  'AC/DC': 8283420177,
#  'P!nk': 8243802966,
#  'John Mayer': 8243443329,
#  'Logic': 8221159539,
#  'Migos': 8212730428,
#  'Trippie Redd': 8169854684,
#  'Gunna': 8136453038,
#  'Tyga': 8136081475,
#  'James Arthur': 8094663482,
#  'Little Mix': 8025705397,
#  'Macklemore': 7934784607,
#  'ZAYN': 7926581878,
#  'DJ Snake': 7893987604,
#  'Lauv': 7860150086,
#  'Kodak Black': 7853951418,
#  'Tyler, The Creator': 7852572852,
#  'Frank Ocean': 7842180179,
#  'A$AP Rocky': 7788610912,
#  'YoungBoy Never Broke Again': 7762762379,
#  'NF': 7715473739,
#  'Tiësto': 7713821346,
#  '5 Seconds of Summer': 7672003639,
#  'A Boogie Wit da Hoodie': 7634446872,
#  'Zedd': 7585730125,
#  'Romeo Santos': 7485543396,
#  'Robin Schulz': 7470013873,
#  'Green Day': 7403734026,
#  '$uicideboy$': 7392060042,
#  'Nirvana': 7295132559,
#  'SZA': 7269204057,
#  'Luis Miguel': 7267478981,
#  'DJ Khaled': 7262608327,
#  'Metro Boomin': 7262115562,
#  'Justin Timberlake': 7225331308,
#  'Bob Marley & The Wailers': 7206364367,
#  'BLACKPINK': 7206360244,
#  'Machine Gun Kelly': 7175506952,
#  'blackbear': 7107987469,
#  'Black Eyed Peas': 7055175439,
#  'Anne-Marie': 6995284822,
#  'Lewis Capaldi': 6958006277,
#  'Clean Bandit': 6956364284,
#  'JAY-Z': 6923840435,
#  'Marília Mendonça': 6909001088,
#  'Zara Larsson': 6878581725,
#  'Bebe Rexha': 6836453644,
#  'Anitta': 6801733116,
#  'Enrique Iglesias': 6764228183,
#  'Fleetwood Mac': 6753161276,
#  'The Rolling Stones': 6727427341,
#  'The Neighbourhood': 6718687991,
#  'Pink Floyd': 6714780376,
#  'Britney Spears': 6671486096,
#  'Michael Bublé': 6667559320,
#  'The Kid LAROI': 6647734218,
#  "Guns N' Roses": 6615411211,
#  'Flo Rida': 6555092666,
#  'Camilo': 6519784854,
#  'Ty Dolla $ign': 6503653017,
#  'Kid Cudi': 6488863340,
#  'Disney': 6480840953,
#  'Becky G': 6434404802,
#  'Jonas Blue': 6422049491,
#  'Russ': 6409448257,
#  'Luis Fonsi': 6388525172,
#  '2Pac': 6328173362,
#  'Reik': 6327803667,
#  '50 Cent': 6248846278,
#  'Childish Gambino': 6247735359,
#  'Gorillaz': 6243417623,
#  'Ava Max': 6182963810,
#  'Jhay Cortez': 6170553828,
#  'Bastille': 6158728878,
#  'Joji': 6150774573,
#  'Polo G': 6136158071,
#  'Lorde': 6006934967,
#  'Usher': 5981518153,
#  'Hozier': 5967126876,
#  'David Bowie': 5960976370,
#  'Banda MS de Sergio Lizárraga': 5924856095,
#  'Luke Combs': 5890199848,
#  'Mariah Carey': 5888465193,
#  'Skrillex': 5881756686,
#  'Christian Nodal': 5835820936,
#  'Big Sean': 5791066758,
#  'The Killers': 5774550053,
#  'Alessia Cara': 5768256100,
#  'Foo Fighters': 5761240710,
#  'Playboi Carti': 5756121719,
#  'French Montana': 5687956941,
#  'Tory Lanez': 5657531451,
#  'U2': 5622227589,
#  'Manuel Turizo': 5610907877,
#  'Meek Mill': 5609538227,
#  'Jack Harlow': 5606152807,
#  'blink-182': 5568505079,
#  'Led Zeppelin': 5554421214,
#  'Daft Punk': 5551691330,
#  'Radiohead': 5531324257,
#  'Jorge & Mateus': 5486263204,
#  'Henrique & Juliano': 5466963460,
#  'Roddy Ricch': 5446354074,
#  'Elvis Presley': 5442877510,
#  'Meghan Trainor': 5418874209,
#  'Paulo Londra': 5408739140,
#  'Labrinth': 5408385063,
#  'John Legend': 5384405995,
#  'Frank Sinatra': 5382091415,
#  'Don Omar': 5374011725,
#  'Morgan Wallen': 5345429164,
#  'System Of A Down': 5306747245,
#  'Megan Thee Stallion': 5274621614,
#  'Rita Ora': 5257167753,
#  'The 1975': 5232430866,
#  'Rae Sremmurd': 5226974030,
#  'Tame Impala': 5214042684,
#  'Melanie Martinez': 5194199440,
#  'TWICE': 5181586735,
#  'Muse': 5181150140,
#  'Gucci Mane': 5179422858,
#  'Jack Johnson': 5176854131,
#  'The Notorious B.I.G.': 5171977853,
#  'Troye Sivan': 5103726645,
#  'Bon Jovi': 5101338141,
#  'Paramore': 5095348178,
#  'Mumford & Sons': 5088124853,
#  'ABBA': 5004152913,
#  '6ix9ine': 4988907666,
#  'Slipknot': 4980473881,
#  'Bazzi': 4941186159,
#  'Gusttavo Lima': 4938141476,
#  'Oasis': 4924851582,
#  'Morat': 4919640815,
#  'Sean Paul': 4910936441,
#  'Felix Jaehn': 4901374743,
#  'The Lumineers': 4894719810,
#  'Justin Quiles': 4878976278,
#  'Dalex': 4871872181,
#  'Duki': 4869537547,
#  'Swae Lee': 4836929180,
#  'Hailee Steinfeld': 4815845560,
#  'Julia Michaels': 4811539257,
#  'Rammstein': 4781710534,
#  'Alicia Keys': 4777678003,
#  'Alok': 4738018362,
#  'Madonna': 4718747892,
#  'Jess Glynne': 4712325038,
#  'Zion & Lennox': 4710887632,
#  'Disclosure': 4690114197,
#  'Christina Aguilera': 4686000540,
#  'Kings of Leon': 4669462543,
#  '6LACK': 4650333571,
#  'Cheat Codes': 4629305378,
#  'Tove Lo': 4629278952,
#  'Creedence Clearwater Revival': 4623595600,
#  'Florence + The Machine': 4614759836,
#  'Florida Georgia Line': 4609041041,
#  'My Chemical Romance': 4607083284,
#  'Alesso': 4597495128,
#  'Arijit Singh': 4573567798,
#  'Glass Animals': 4554159224,
#  'The Script': 4553052747,
#  'Zé Neto & Cristiano': 4540609590,
#  'Whitney Houston': 4519561495,
#  'Chance the Rapper': 4517223691,
#  'Piso 21': 4511325667,
#  'Five Finger Death Punch': 4506617068,
#  'Bruce Springsteen': 4480464759,
#  'Arcangel': 4475257907,
#  'Nickelback': 4469299972,
#  'Fifth Harmony': 4468944634,
#  'Lenny Tavárez': 4449161492,
#  'Jason Mraz': 4439148339,
#  'Galantis': 4427621050,
#  'Avril Lavigne': 4418987832,
#  'Glee Cast': 4375931294,
#  'Bring Me The Horizon': 4372894185,
#  'Ne-Yo': 4368629006,
#  'Lil Durk': 4367616218,
#  'Kane Brown': 4364488364,
#  'Kehlani': 4361626721,
#  'Kevin Gates': 4359021971,
#  'Niall Horan': 4338726666,
#  'Bryson Tiller': 4330601767,
#  'Jonas Brothers': 4329888033,
#  'Bizarrap': 4326642648,
#  'Capital Bra': 4317253980,
#  'Lil Tjay': 4313086274,
#  'Snoop Dogg': 4300203668,
#  'Macklemore & Ryan Lewis': 4290529937,
#  'Lil Tecca': 4273063329,
#  'Luke Bryan': 4267128439,
#  'Natti Natasha': 4253199571,
#  'Wisin': 4226257427,
#  'Aerosmith': 4219398737,
#  'Vance Joy': 4216274820,
#  'Kelly Clarkson': 4206190955,
#  'Alejandro Fernández': 4201269620,
#  'Stevie Wonder': 4196723912,
#  'Jennifer Lopez': 4186796728,
#  'Johnny Cash': 4174390143,
#  'Maná': 4119964379,
#  'Thomas Rhett': 4112832625,
#  'Ryan Lewis': 4110355782,
#  'Hans Zimmer': 4092359874,
#  'NAV': 4088499280,
#  'Lil Pump': 4054627650,
#  'Pearl Jam': 4052231789,
#  'James Bay': 4051355922,
#  'Disturbed': 4034857022,
#  'YG': 4034206176,
#  'Amy Winehouse': 4024161318,
#  'Wisin & Yandel': 4004531845,
#  'YNW Melly': 3991996348,
#  'Lil Skies': 3968361888,
#  'Nio Garcia': 3960430779,
#  'Tones And I': 3957800698,
#  'Kesha': 3955337905,
#  'Backstreet Boys': 3949466238,
#  'Aventura': 3943857084,
#  'Flume': 3942056858,
#  'Dr. Dre': 3941098327,
#  'Miguel': 3933509386,
#  'Jul': 3931452487,
#  'Lizzo': 3911061177,
#  'Billy Joel': 3885486622,
#  'ROSALÍA': 3871106303,
#  'Calibre 50': 3859723768,
#  'Phil Collins': 3836785174,
#  'Matheus & Kauan': 3831562276,
#  'Akon': 3813017846,
#  'Jason Aldean': 3797816243,
#  'Eagles': 3784792723,
#  'George Ezra': 3745977355,
#  'Yandel': 3731724067,
#  'Prince Royce': 3724376964,
#  'The Offspring': 3713219015,
#  '24kGoldn': 3705648954,
#  'Three Days Grace': 3698665397,
#  'Wesley Safadão': 3698314476,
#  'Anderson .Paak': 3694145511,
#  'The Strokes': 3688560624,
#  'Don Toliver': 3686151351,
#  'Conan Gray': 3684167999,
#  'Dan + Shay': 3680653230,
#  'Rex Orange County': 3678846424,
#  'Jeremih': 3674742679,
#  'benny blanco': 3661450439,
#  'Cartel De Santa': 3655552123,
#  'Avenged Sevenfold': 3634693374,
#  'Ricardo Arjona': 3629270035,
#  'Céline Dion': 3626954646,
#  'Ninho': 3614658124,
#  'Måneskin': 3603994073,
#  'Alejandro Sanz': 3592290895,
#  'Lin-Manuel Miranda': 3592135787,
#  'Ricky Martin': 3568196300,
#  'Jessie J': 3563453628,
#  'Lost Frequencies': 3556401142,
#  'Danny Ocean': 3541587214,
#  'Maiara & Maraisa': 3531976169,
#  'Steve Aoki': 3527393369,
#  'Lil Mosey': 3517585999,
#  'Marc Anthony': 3504819748,
#  'H.E.R.': 3476314834,
#  'Nelly': 3464996085,
#  'Charli XCX': 3464311470,
#  'Pablo Alborán': 3437809914,
#  '2 Chainz': 3429709034,
#  'Train': 3423789545,
#  'Passenger': 3415074486,
#  'Lukas Graham': 3410790500,
#  'Mark Ronson': 3400585305,
#  'CNCO': 3399584158,
#  'Foster The People': 3393389914,
#  'Calum Scott': 3392200109,
#  'Dire Straits': 3390427781,
#  'Alec Benjamin': 3389530976,
#  'Daniel Caesar': 3387218135,
#  'Bee Gees': 3383127730,
#  'Tate McRae': 3371616079,
#  'Bryan Adams': 3365887458,
#  'Summer Walker': 3363193393,
#  'Trey Songz': 3357005694,
#  'Bob Dylan': 3352960099,
#  'Grupo Firme': 3348434531,
#  'Armin van Buuren': 3340463682,
#  'Rels B': 3327775726,
#  'Boyce Avenue': 3287510482,
#  'Pentatonix': 3285741959,
#  'Ski Mask The Slump God': 3276018075,
#  'R3HAB': 3274814964,
#  'LANY': 3270335409,
#  'Tainy': 3255357184,
#  'PARTYNEXTDOOR': 3243038851,
#  'La Arrolladora Banda El Limón De Rene Camacho': 3236920653,
#  'James Blunt': 3226977012,
#  'The Police': 3222974290,
#  'Cage The Elephant': 3219794411,
#  'Fetty Wap': 3217362515,
#  'Jeremy Zucker': 3215507829,
#  'Dean Lewis': 3212555492,
#  'John Williams': 3211135011,
#  'Bibi Blocksberg': 3207503226,
#  'Outkast': 3196044035,
#  'Becky Hill': 3194644880,
#  'Sam Hunt': 3189888914,
#  'Sigala': 3182931037,
#  'Carlos Vives': 3181877775,
#  'Jhené Aiko': 3178645401,
#  'Rudimental': 3160482589,
#  'ScHoolboy Q': 3147481533,
#  'Marvin Gaye': 3143836699,
#  'Offset': 3141568579,
#  'Stray Kids': 3120244998,
#  'Sam Feldt': 3107699941,
#  'Iron Maiden': 3103589124,
#  'Zac Brown Band': 3100596570,
#  'Jax Jones': 3080700501,
#  'ILLENIUM': 3076454009,
#  'Joan Sebastian': 3063649523,
#  'Hillsong Worship': 3062386056,
#  'Kali Uchis': 3055543671,
#  'Skillet': 3050996601,
#  'Juanes': 3046714537,
#  'Blake Shelton': 3044373576,
#  'alt-J': 3025145409,
#  'Chris Stapleton': 3024791697,
#  'Lil Yachty': 3023049234,
#  'Quavo': 3022133428,
#  'Los Ángeles Azules': 3020957267,
#  'NLE Choppa': 3018674271,
#  'Feid': 3009497561,
#  'Journey': 3008391718,
#  'The Vamps': 3006139960,
#  'BROCKHAMPTON': 3002168774,
#  'Soda Stereo': 3000230369,
#  'The Black Keys': 2995726401,
#  'Liam Payne': 2990601102,
#  'Mike Posner': 2987016135,
#  'Weezer': 2970962554,
#  'Korn': 2968839699,
#  'El Alfa': 2966087446,
#  'Tim McGraw': 2964965833,
#  'Madison Beer': 2958196752,
#  'Imanbek': 2957190912,
#  'Rise Against': 2955084542,
#  'The Doors': 2953574273,
#  'Maren Morris': 2940819852,
#  'Mau y Ricky': 2936936952,
#  'Bon Iver': 2928247210,
#  'RAF Camora': 2926653996,
#  'Lunay': 2925162457,
#  'Maria Becerra': 2921291638,
#  'Carly Rae Jepsen': 2921086654,
#  "Why Don't We": 2917638636,
#  'Vicente Fernández': 2910574978,
#  'A$AP Ferg': 2903470782,
#  'Juan Gabriel': 2901846633,
#  'JP Cooper': 2895291874,
#  'PNL': 2889660746,
#  'The Cure': 2882831026,
#  'Mabel': 2874150906,
#  'Birdy': 2864553572,
#  'Papa Roach': 2861296786,
#  'MARINA': 2860314714,
#  'Jesse & Joy': 2856285668,
#  'T.I.': 2848098002,
#  'SAINt JHN': 2841651735,
#  'Bradley Cooper': 2832555130,
#  'Bonez MC': 2815182209,
#  'Noah Cyrus': 2813340209,
#  'C. Tangana': 2808496289,
#  'MEDUZA': 2806488850,
#  'Ludovico Einaudi': 2791367383,
#  'Depeche Mode': 2784128682,
#  "Destiny's Child": 2775187867,
#  'Kenny Chesney': 2772827226,
#  'Paul McCartney': 2767237931,
#  'Eric Church': 2759312007,
#  'Dave': 2749490108,
#  'Eric Clapton': 2747310452,
#  'KHEA': 2743045197,
#  'EXO': 2725969831,
#  'Simon & Garfunkel': 2718178664,
#  'TINI': 2717301467,
#  'Norah Jones': 2714788741,
#  'Iggy Azalea': 2703950724,
#  'George Michael': 2703100036,
#  'Jay Wheeler': 2701443856,
#  'De La Ghetto': 2695370320,
#  'Nacho': 2692139444,
#  'bbno$': 2691389490,
#  'The Beach Boys': 2687373992,
#  'The Game': 2686873055,
#  'Bibi und Tina': 2680606898,
#  'Ufo361': 2676667284,
#  'R.E.M.': 2665630567,
#  'Aminé': 2661288241,
#  'Normani': 2658470073,
#  'AJR': 2649403045,
#  'Christina Perri': 2646573107,
#  'X Ambassadors': 2621685116,
#  'Breaking Benjamin': 2619625553,
#  'Earth, Wind & Fire': 2606939541,
#  'Hillsong UNITED': 2599812772,
#  'Rod Wave': 2598143018,
#  'Nick Jonas': 2588951174,
#  'Rich The Kid': 2587583439,
#  'Jimi Hendrix': 2585036209,
#  'The Smiths': 2582782853,
#  'Dermot Kennedy': 2581422010,
#  'SEVENTEEN': 2580817471,
#  'Milky Chance': 2580709652,
#  'Volbeat': 2579498906,
#  'TOTO': 2575874146,
#  'Dimitri Vegas & Like Mike': 2572306129,
#  'Sabrina Carpenter': 2569519803,
#  'Robbie Williams': 2557179105,
#  'Matoma': 2555408299,
#  'Years & Years': 2550829792,
#  'Mitski': 2547259202,
#  'Jon Bellion': 2543285648,
#  'The xx': 2542777584,
#  'Van Morrison': 2542234398,
#  'Nelly Furtado': 2534235066,
#  'Luciano': 2526245631,
#  'B.o.B': 2525038408,
#  'T-Pain': 2522886931,
#  'Lynyrd Skynyrd': 2519169676,
#  'Stormzy': 2500482085,
#  'Sfera Ebbasta': 2496062465,
#  'Rick Ross': 2491175711,
#  'Cali Y El Dandee': 2490592473,
#  'Kid Ink': 2489130300,
#  'Shinedown': 2479535960,
#  'Natanael Cano': 2475463509,
#  'Van Halen': 2466995848,
#  'Limp Bizkit': 2466419030,
#  'The Fray': 2463436621,
#  'Samra': 2461380410,
#  'The Cranberries': 2460868337,
#  'Black Sabbath': 2459611513,
#  'All Time Low': 2459397211,
#  'DNCE': 2458758461,
#  'El Fantasma': 2457887099,
#  'Damso': 2448621601,
#  'Andy Grammer': 2431629519,
#  'Rage Against The Machine': 2430839934,
#  'Luan Santana': 2430000476,
#  'Aitana': 2428820555,
#  'Juan Magán': 2428032283,
#  'KYLE': 2420485330,
#  'Keith Urban': 2416463388,
#  'Joel Corry': 2415759211,
#  'Daryl Hall & John Oates': 2405798697,
#  'Sabaton': 2399679054,
#  'MGMT': 2396610713,
#  'Kodaline': 2386258538,
#  'Aya Nakamura': 2386108307,
#  'Plan B': 2383828013,
#  "Rag'n'Bone Man": 2382013837,
#  'Shaggy': 2381998464,
#  'Of Monsters and Men': 2380280721,
#  'Rod Stewart': 2379541913,
#  'The White Stripes': 2377686382,
#  'Hollywood Undead': 2373538882,
#  'Mac DeMarco': 2366844862,
#  'Gerardo Ortiz': 2362366616,
#  'A Day To Remember': 2357711163,
#  'Quinn XCII': 2350578227,
#  'Ice Cube': 2344900860,
#  'Clairo': 2340931623,
#  'Swedish House Mafia': 2340727040,
#  'League of Legends': 2340011159,
#  'Eladio Carrion': 2339040331,
#  'Lofi Fruits Music': 2329999921,
#  'Prince': 2327965052,
#  'Os Barões Da Pisadinha': 2325967532,
#  'Brytiago': 2325768055,
#  'Casper Magico': 2324673947,
#  'José José': 2323517374,
#  'Evanescence': 2320082358,
#  'Sublime': 2317831260,
#  'Die drei !!!': 2317017983,
#  'Tom Odell': 2313290532,
#  'GIMS': 2311019564,
#  'Chencho Corleone': 2307620270,
#  'Cigarettes After Sex': 2297049191,
#  'Bryant Myers': 2296987693,
#  'Axwell /\\ Ingrosso': 2295622491,
#  'Red Velvet': 2293993571,
#  'George Strait': 2293305564,
#  'Carlos Rivera': 2291158958,
#  'Carrie Underwood': 2287677862,
#  'Enya': 2281284138,
#  'Pedro Capó': 2277124460,
#  'girl in red': 2264464619,
#  'Aretha Franklin': 2259373196,
#  'Ozzy Osbourne': 2258551820,
#  'Scorpions': 2257465297,
#  'Nas': 2255035088,
#  'ODESZA': 2251141203,
#  'Joyner Lucas': 2250754960,
#  'Ali Gatie': 2236769112,
#  'Mustard': 2234505311,
#  'PnB Rock': 2228993718,
#  'Zoé': 2227159139,
#  'Goodboys': 2225051739,
#  'KISS': 2222550482,
#  'WALK THE MOON': 2213255179,
#  'Danna Paola': 2212142768,
#  'Don Diablo': 2200628570,
#  'Jorja Smith': 2195160357,
#  'Los Tigres Del Norte': 2195087945,
#  'Gryffin': 2193509712,
#  'RAYE': 2192939509,
#  'Junior H': 2190309741,
#  'The Smashing Pumpkins': 2172954938,
#  'Sum 41': 2172099956,
#  'Alan Jackson': 2168305190,
#  'Marco Antonio Solís': 2167056600,
#  'WILLOW': 2162026224,
#  'Ella Mai': 2161392693,
#  'Marilyn Manson': 2156699936,
#  'Joey Bada$$': 2149110284,
#  'Lord Huron': 2147142104,
#  'Sleeping At Last': 2146420809,
#  'Astrid S': 2145022194,
#  'TKKG': 2141387313,
#  'Sido': 2141006547,
#  'TOMORROW X TOGETHER': 2136382863,
#  'Colbie Caillat': 2133775510,
#  'Banda El Recodo': 2127016589,
#  'Rascal Flatts': 2124400562,
#  'Dolly Parton': 2122503850,
#  '3 Doors Down': 2122358023,
#  'Wale': 2117359552,
#  'Moneybagg Yo': 2117349736,
#  'Electric Light Orchestra': 2112872480,
#  'Two Door Cinema Club': 2112307879,
#  'Hardwell': 2109914592,
#  'Brent Faiyaz': 2107146096,
#  'Chase Atlantic': 2105375619,
#  'Kontra K': 2103318066,
#  'iann dior': 2102922842,
#  'Powfu': 2092377791,
#  'Bethel Music': 2092086801,
#  'JID': 2089652973,
#  'Louis Tomlinson': 2086972274,
#  'The Clash': 2085949767,
#  'Noriel': 2083887397,
#  'gnash': 2083638974,
#  'MC Kevinho': 2082054602,
#  'David Bisbal': 2078820031,
#  'Pharrell Williams': 2077074226,
#  'Gera MX': 2071389389,
#  'Kacey Musgraves': 2070185118,
#  'Luísa Sonza': 2068349876,
#  'Leon Bridges': 2064776224,
#  'Chief Keef': 2064287110,
#  'Martin Jensen': 2063060185,
#  'Stromae': 2062404120,
#  'Annie Lennox': 2062340171,
#  'Ruth B.': 2057984888,
#  'NEFFEX': 2056583318,
#  'Duran Duran': 2052957469,
#  'Jaden': 2050432169,
#  'Bing Crosby': 2043924592,
#  'Seeb': 2043477578,
#  'Ms. Lauryn Hill': 2040646969,
#  'Arizona Zervas': 2039690926,
#  'Santa Fe Klan': 2039138179,
#  'Miracle Tones': 2031004961,
#  'Regard': 2029133220,
#  'Westlife': 2026058221,
#  'The Kooks': 2024254904,
#  'Mike WiLL Made-It': 2021477415,
#  'Elevation Worship': 2019584095,
#  'Internet Money': 2018584676,
#  'M83': 2015140978,
#  'Portugal. The Man': 2003183409,
#  'R. Kelly': 2002013664,
#  'Saweetie': 2000089741,
#  'Dilsinho': 1996437258,
#  'Charlie Brown Jr.': 1995556424,
#  'Ha*Ash': 1989802115,
#  'Gwen Stefani': 1988899782,
#  'Mötley Crüe': 1986516487,
#  'Jessie Reyez': 1982350944,
#  'Owl City': 1980070565,
#  'Apache 207': 1977481576,
#  'Nekfeu': 1977245131,
#  'Queens of the Stone Age': 1973861331,
#  'Cosculluela': 1973500286,
#  'Keane': 1971059662,
#  'Tee Grizzley': 1970417387,
#  'Ezhel': 1969446772,
#  "Gigi D'Agostino": 1961013546,
#  'DMX': 1959946681,
#  'Bruno & Marrone': 1959875993,
#  'Yung Gravy': 1959097379,
#  'Desiigner': 1955514520,
#  'Timmy Trumpet': 1954597157,
#  'Thirty Seconds To Mars': 1954498523,
#  'Denzel Curry': 1952649461,
#  'Jay Chou': 1951129090,
#  'Chelsea Cutler': 1950899986,
#  'Alex Rose': 1949166634,
#  'Olly Murs': 1946478736,
#  'Vampire Weekend': 1945573015,
#  'Miranda Lambert': 1938843377,
#  'Santana': 1933599979,
#  'The Goo Goo Dolls': 1933399868,
#  'Aloe Blacc': 1930856165,
#  'Wham!': 1930785286,
#  'Willy William': 1930491419,
#  'MAX': 1929553352,
#  'Dierks Bentley': 1923717525,
#  'The Who': 1923165495,
#  'Granular': 1919564121,
#  'Stefflon Don': 1914806534,
#  'La Oreja de Van Gogh': 1912311819,
#  'OMI': 1908116986,
#  'Alice In Chains': 1902125921,
#  'Giveon': 1901077447,
#  'John Lennon': 1900843192,
#  'Los Temerarios': 1899241961,
#  'Loud Luxury': 1898927877,
#  'Ghostemane': 1897237706,
#  'Snow Patrol': 1897170969,
#  'beabadoobee': 1893281518,
#  'Lee Brice': 1893216404,
#  'Trevor Daniel': 1893164011,
#  'James TW': 1892634482,
#  'Louis Armstrong': 1888813523,
#  'Beret': 1887419481,
#  'Shania Twain': 1885781696,
#  'Calle 13': 1883809656,
#  'Booba': 1880281066,
#  'Niska': 1879295266,
#  'Ciara': 1875900807,
#  'Incubus': 1872492242,
#  'MØ': 1867886470,
#  'Mon Laferte': 1867546187,
#  'Conor Maynard': 1867293612,
#  'Ella Fitzgerald': 1865209139,
#  'Sting': 1864917481,
#  'Vintage Culture': 1863460359,
#  'Kevin Roldan': 1860423142,
#  'Blueface': 1856041642,
#  'Nat King Cole': 1853717658,
#  'Yo Gotti': 1852943310,
#  'Lady A': 1850637526,
#  'Two Feet': 1850083119,
#  'Thalia': 1849494711,
#  'Taio Cruz': 1849088545,
#  'Old Dominion': 1846826397,
#  'Dean Martin': 1839950779,
#  'Oliver Tree': 1839830515,
#  'John Newman': 1839265446,
#  'CRO': 1837987132,
#  'PNAU': 1837143273,
#  'ANAVITÓRIA': 1836487394,
#  'Sara Bareilles': 1829209796,
#  'Michael Silverman': 1827043186,
#  'Burna Boy': 1821371663,
#  'Surfaces': 1819802511,
#  'Chayanne': 1817989260,
#  'a-ha': 1815725128,
#  'The Jackson 5': 1814148449,
#  'Fergie': 1813098972,
#  'The Pussycat Dolls': 1813039711,
#  'Roxette': 1810253500,
#  'Leona Lewis': 1806698865,
#  'Matuê': 1805676631,
#  'Natalia Lafourcade': 1805496403,
#  'Mora': 1805158864,
#  'Dynoro': 1804491187,
#  'Los Tucanes De Tijuana': 1804035346,
#  'AJ Tracey': 1802672139,
#  'LUDMILLA': 1799762330,
#  'Sean Kingston': 1798965211,
#  'Guaynaa': 1797383497,
#  'Steve Lacy': 1794556932,
#  'Jon Pardi': 1793562040,
#  'fun.': 1792718438,
#  'Ben Howard': 1790617769,
#  'Tears For Fears': 1785149316,
#  'Mike Perry': 1784903805,
#  'Lalo Ebratt': 1773683414,
#  'Oliver Heldens': 1773243390,
#  'Martin Solveig': 1772167780,
#  'Nicki Nicole': 1771051853,
#  'Darell': 1768464822,
#  'CHVRCHES': 1766235284,
#  'Julieta Venegas': 1760785705,
#  'Kylie Minogue': 1760059922,
#  'Gente De Zona': 1756631831,
#  'Deftones': 1750174564,
#  'Melendi': 1749960220,
#  'Seether': 1748931621,
#  'Baby Keem': 1748313318,
#  'DJ Luian': 1747734090,
#  'MKTO': 1746963141,
#  'Mambo Kingz': 1745059565,
#  'Lionel Richie': 1743379490,
#  'IU': 1743026779,
#  'Lil Dicky': 1741821934,
#  'Intocable': 1741554669,
#  'Sin Bandera': 1738742132,
#  'Daya': 1735378090,
#  'Chris Young': 1733928126,
#  'Tech N9ne': 1733262095,
#  'Arcade Fire': 1731328594,
#  'Rich Brian': 1727170764,
#  'Mother Mother': 1726527097,
#  'Yusuf / Cat Stevens': 1726512987,
#  'Kina': 1723333633,
#  'MAGIC!': 1721727530,
#  'Greeicy': 1720259336,
#  'Simple Plan': 1719642286,
#  'Sofía Reyes': 1719104610,
#  'Dido': 1718183561,
#  'Paul Simon': 1715931271,
#  'Dennis Lloyd': 1715531867,
#  'Alfredo Olivas': 1713355709,
#  'Wolfgang Amadeus Mozart': 1712607320,
#  'Tiago PZK': 1709750883,
#  'Pineapple StormTv': 1707906194,
#  'DENNIS': 1705396553,
#  'YUNGBLUD': 1703601205,
#  'Summer Cem': 1702570591,
#  'Sade': 1701116678,
#  'Eslabon Armado': 1699114472,
#  'Juan Luis Guerra 4.40': 1695901682,
#  'La Adictiva Banda San José de Mesillas': 1695830013,
#  'KSI': 1695358834,
#  'Bullet For My Valentine': 1694804867,
#  'Selena': 1693151147,
#  'Jack Ü': 1685398303,
#  'Nina Simone': 1682102220,
#  'Kollegah': 1676987056,
#  'Bea Miller': 1675218584,
#  'Nipsey Hussle': 1669099192,
#  'Cyndi Lauper': 1668152364,
#  'Juicy J': 1666667173,
#  'Max Richter': 1666056201,
#  'Los Bukis': 1665301634,
#  'Otis Redding': 1664195345,
#  'Dominic Fike': 1660702806,
#  'Kungs': 1657734274,
#  '*NSYNC': 1656401553,
#  'Jasmine Thompson': 1651309359,
#  'Willie Nelson': 1649521446,
#  'Tina Turner': 1649451408,
#  'Yellow Claw': 1646156795,
#  'Lily Allen': 1643394520,
#  'will.i.am': 1641904383,
#  'Sasha Alex Sloan': 1637138656,
#  'Silk Sonic': 1635262002,
#  'NCT 127': 1633145081,
#  'deadmau5': 1633102099,
#  'Benjamin Blümchen': 1632183811,
#  'Beastie Boys': 1631483593,
#  'Ferrugem': 1630991997,
#  'Trueno': 1625212488,
#  'Tom Walker': 1621938619,
#  'Angus & Julia Stone': 1621262836,
#  'AURORA': 1620462028,
#  'Wallows': 1617420796,
#  'Bill Withers': 1616684397,
#  'Camila': 1614888793,
#  'The National': 1612789597,
#  'ZZ Top': 1609888997,
#  'KALEO': 1609214165,
#  'Tracy Chapman': 1603955839,
#  'Mary J. Blige': 1603823302,
#  'Jowell & Randy': 1598782161,
#  'Brad Paisley': 1594358812,
#  'The Score': 1590492855,
#  'Los Enanitos Verdes': 1589791667,
#  'Gavin James': 1589066720,
#  'Lenny Kravitz': 1586945030,
#  'Tungevaag': 1584806652,
#  'Frédéric Chopin': 1580987576,
#  'Ramin Djawadi': 1576132499,
#  'Tyler Childers': 1575879683,
#  'Brett Young': 1574718551,
#  'BØRNS': 1573109788,
#  'Dadju': 1570782544,
#  'Audioslave': 1568164155,
#  "Olivia O'Brien": 1567268080,
#  'Sleepy Hallow': 1566837791,
#  'Banda Los Recoditos': 1564662688,
#  'Kiiara': 1561088103,
#  'Mr. Probz': 1559887114,
#  'Sufjan Stevens': 1559839764,
#  'Alvaro Soler': 1558833906,
#  'Pink Sweat$': 1558351053,
#  'King Von': 1557609173,
#  'Diego & Victor Hugo': 1557334571,
#  'Joaquín Sabina': 1554442660,
#  'Ella Henderson': 1553412941,
#  'Blur': 1551692610,
#  'Ofenbach': 1550940003,
#  'Lykke Li': 1549963169,
#  'Cher': 1549863381,
#  'Lil Kleine': 1549145488,
#  '(G)I-DLE': 1549107296,
#  'Skepta': 1545159107,
#  'Falling In Reverse': 1544740243,
#  'Aleman': 1543845576,
#  'Will Smith': 1542201832,
#  'Kris Kross Amsterdam': 1540779399,
#  'Salmo': 1539540910,
#  'Toby Keith': 1539260688,
#  'Timbaland': 1538740572,
#  'Beach House': 1537837100,
#  'Snakehips': 1537501501,
#  'YOASOBI': 1533599947,
#  'ITZY': 1531845087,
#  'Pusha T': 1530816646,
#  'Spice Girls': 1530766752,
#  'Río Roma': 1527525300,
#  'Bo Burnham': 1527212746,
#  'Oh Wonder': 1522982587,
#  'UB40': 1520229534,
#  'Moby': 1519804913,
#  'Andrea Bocelli': 1518057850,
#  'Cash Cash': 1516224156,
#  'Zendaya': 1514581338,
#  'Topic': 1514111730,
#  'John Denver': 1512762331,
#  'BONES': 1511219763,
#  'Natiruts': 1510821450,
#  'TLC': 1510571033,
#  'Gustavo Cerati': 1509810094,
#  'LIT killah': 1509081134,
#  'Alina Baraz': 1506524901,
#  'Lauren Daigle': 1506508915,
#  'Official HIGE DANdism': 1506088256,
#  'Pixies': 1505325659,
#  'Dread Mar I': 1503218350,
#  'Mc Don Juan': 1500472460,
#  'Thiaguinho': 1498417630,
#  'Evaluna Montaner': 1495747834,
#  'Capo Plaza': 1494955350,
#  'MF DOOM': 1494366089,
#  'Petit Biscuit': 1494185761,
#  'Gloria Trevi': 1493626591,
#  'Gym Class Heroes': 1493450694,
#  'Maggie Lindemann': 1492524310,
#  'Jeezy': 1485078408,
#  'Talking Heads': 1484242370,
#  'Bruno Martini': 1482924670,
#  'Supertramp': 1480511283,
#  'Hungria Hip Hop': 1480092466,
#  'Wu-Tang Clan': 1479460962,
#  'Vince Staples': 1478107395,
#  'Brantley Gilbert': 1477281228,
#  'Tori Kelly': 1473981175,
#  'Counting Crows': 1473624597,
#  'Marracash': 1472923263,
#  'Foreigner': 1468972124,
#  'Andrés Calamaro': 1463467941,
#  'Tom Petty and the Heartbreakers': 1463007847,
#  'Hombres G': 1461546570,
#  'Lupe Fiasco': 1458913538,
#  '$NOT': 1456594009,
#  'Upchurch': 1451882160,
#  'Canserbero': 1451762300,
#  'ZHU': 1450364098,
#  'Cristian Castro': 1449606688,
#  'Megadeth': 1449001793,
#  'D-Block Europe': 1448961530,
#  'Bryce Vine': 1444948521,
#  'Gustavo Mioto': 1444828975,
#  'Showtek': 1441997312,
#  'Pabllo Vittar': 1440938225,
#  'Kelly Rowland': 1439718750,
#  'The All-American Rejects': 1439069693,
#  'Jack & Jack': 1438739447,
#  'Ben&Ben': 1437489824,
#  'The Head And The Heart': 1436917213,
#  'ONE OK ROCK': 1436289806,
#  'Melim': 1435884104,
#  'Jacquees': 1433486084,
#  'RÜFÜS DU SOL': 1431266723,
#  'SCH': 1430189357,
#  'Young the Giant': 1429779508,
#  'Gemitaiz': 1429778231,
#  'Central Cee': 1428646963,
#  'Empire of the Sun': 1428482992,
#  'Alanis Morissette': 1426836551,
#  'Icona Pop': 1426680056,
#  'Dustin Lynch': 1426154511,
#  'The Temptations': 1425942696,
#  'Simone & Simaria': 1425339491,
#  'Gotye': 1424591618,
#  'NIKI': 1422920850,
#  'Duke Dumont': 1422096182,
#  'Laura Pausini': 1421622604,
#  'Beck': 1420597420}

# %%
# Now, for each row in the df I am checking if the artist has a corresponding key in the dict above, if it does I am adding streams to that row, if not I am adding
# 0 to that row
streams_list = []
for artist in df2["Top Artist"]:
    if artist in artist_streams:
        streams_list.append(artist_streams[artist])
    else:
        streams_list.append(0)

df2["Streams"] = streams_list
df2.head()

streams_list2 = []
for artist in top100_2000["artist"]:
    if artist in artist_streams:
        streams_list2.append(artist_streams[artist])
    else:
        streams_list2.append(0)

top100_2000["Streams"] = streams_list2

# %%
top100_2000.rename(columns = {"danceability ": "danceability", "speechiness ": "speechiness"}, 
          inplace = True)
top100_2000_updated = top100_2000[["bpm", "energy", "dB", "liveness", "duration", "acousticness", "danceability", "speechiness", "popularity", "Streams"]]
top100_2000_updated
# Out:
#       bpm  energy  dB  liveness  duration  acousticness  danceability  \
# 0     118      68  -4         3       200             6            71
# 1     120      59  -8        35       174            44            78
# 2      95      64  -7        17       195            74            77
# 3     133      81  -8        25       131            25            70
# 4      98      62  -6         8       222            42            72
# ...   ...     ...  ..       ...       ...           ...           ...
# 2380  140      88  -6        10       228            19            60
# 2381  150      90  -4        36       241             0            55
# 2382  100      87  -7         9       255             0            60
# 2383  120      80  -6         7       179             0            65
# 2384   95      64 -10        19       174             0            66
#
#       speechiness  popularity     Streams
# 0               7          98  9940559934
# 1               3          97           0
# 2              14          96  3871106303
# 3               5          96           0
# 4               5          96  7262115562
# ...           ...         ...         ...
# 2380            4          21           0
# 2381            9          16           0
# 2382            5          15           0
# 2383            6          11           0
# 2384            6           5           0
#
# [2385 rows x 10 columns]

# %%
# Matching columns and making sure the scales are the same so that I can concat them. 
updated_songs = df2[["tempo", "energy", "loudness", "liveness", "duration_ms", "acousticness", "danceability", "speechiness", "popularity", "Streams"]]
updated_songs["energy"] = updated_songs["energy"].apply(lambda x: x*1e2)
updated_songs.columns = ["bpm", "energy", "dB", "liveness", "duration", "acousticness", "danceability", "speechiness", "popularity", "Streams"]
updated_songs["liveness"] = updated_songs["liveness"].apply(lambda x: x*1e2)
updated_songs["duration"] = updated_songs["duration"].apply(lambda x: x / 1e3)
updated_songs["acousticness"] = updated_songs["acousticness"].apply(lambda x: x*1e2)
updated_songs["danceability"] = updated_songs["danceability"].apply(lambda x: x*1e2)
updated_songs["speechiness"] = updated_songs["speechiness"].apply(lambda x: x*1e2)


updated_songs = updated_songs.reset_index()
updated_songs = updated_songs.drop(["index"], axis = 1)
updated_songs.head()
# Out:
#        bpm  energy      dB  liveness  duration  acousticness  danceability  \
# 0   80.954    21.1 -20.096      66.5   831.667          98.2          27.9
# 1   60.936    34.1 -12.441      16.0   180.533          73.2          81.9
# 2  110.339    16.6 -14.850      10.1   500.062          96.1          32.8
# 3  100.109    30.9  -9.316      38.1   210.000          96.7          27.5
# 4  101.665    19.3 -10.096      22.9   166.693          95.7          41.8
#
#    speechiness  popularity  Streams
# 0         3.66           4        0
# 1        41.50           5        0
# 2         3.39           5        0
# 3         3.54           3        0
# 4         3.80           2        0

# %%
master_df = pd.concat([updated_songs, top100_2000_updated])
master_df
# Out:
#           bpm  energy      dB  liveness  duration  acousticness  danceability  \
# 0      80.954    21.1 -20.096      66.5   831.667          98.2          27.9
# 1      60.936    34.1 -12.441      16.0   180.533          73.2          81.9
# 2     110.339    16.6 -14.850      10.1   500.062          96.1          32.8
# 3     100.109    30.9  -9.316      38.1   210.000          96.7          27.5
# 4     101.665    19.3 -10.096      22.9   166.693          95.7          41.8
# ...       ...     ...     ...       ...       ...           ...           ...
# 2380  140.000    88.0  -6.000      10.0   228.000          19.0          60.0
# 2381  150.000    90.0  -4.000      36.0   241.000           0.0          55.0
# 2382  100.000    87.0  -7.000       9.0   255.000           0.0          60.0
# 2383  120.000    80.0  -6.000       7.0   179.000           0.0          65.0
# 2384   95.000    64.0 -10.000      19.0   174.000           0.0          66.0
#
#       speechiness  popularity  Streams
# 0            3.66           4        0
# 1           41.50           5        0
# 2            3.39           5        0
# 3            3.54           3        0
# 4            3.80           2        0
# ...           ...         ...      ...
# 2380         4.00          21        0
# 2381         9.00          16        0
# 2382         5.00          15        0
# 2383         6.00          11        0
# 2384         6.00           5        0
#
# [173038 rows x 10 columns]

# %%
# Everything scaled in df

master_scaled = copy.copy(master_df)
scaler = StandardScaler()
 
master_scaled = scaler.fit_transform(master_scaled.to_numpy())
master_scaled = pd.DataFrame(master_scaled, columns=[
  "bpm", "energy", "dB", "liveness", "duration", "acousticness", "danceability", "speechiness", "popularity", "Streams"])

master_scaled
# Out:
#              bpm    energy        dB  liveness  duration  acousticness  \
# 0      -1.172256 -1.025058 -1.526776  2.635600  4.792882      1.287754
# 1      -1.825041 -0.539354 -0.184395 -0.260684 -0.401646      0.623490
# 2      -0.214014 -1.193187 -0.606838 -0.599061  2.147449      1.231956
# 3      -0.547614 -0.658912  0.363604  1.006799 -0.166569      1.247898
# 4      -0.496873 -1.092310  0.226824  0.135046 -0.512057      1.221328
# ...          ...       ...       ...       ...       ...           ...
# 173033  0.753228  1.474450  0.945098 -0.604797 -0.022971     -0.816637
# 173034  1.079327  1.549174  1.295818  0.886359  0.080739     -1.321478
# 173035 -0.551168  1.437088  0.769738 -0.662149  0.192426     -1.321478
# 173036  0.101030  1.175555  0.945098 -0.776853 -0.413876     -1.321478
# 173037 -0.714218  0.577765  0.243658 -0.088627 -0.453765     -1.321478
#
#         danceability  speechiness  popularity   Streams
# 0          -1.475706    -0.381671   -1.260496 -0.332647
# 1           1.586536     1.954125   -1.215431 -0.332647
# 2          -1.197836    -0.398338   -1.215431 -0.332647
# 3          -1.498389    -0.389079   -1.305561 -0.332647
# 4          -0.687462    -0.373029   -1.350626 -0.332647
# ...              ...          ...         ...       ...
# 173033      0.344627    -0.360684   -0.494392 -0.332647
# 173034      0.061086    -0.052042   -0.719716 -0.332647
# 173035      0.344627    -0.298955   -0.764781 -0.332647
# 173036      0.628168    -0.237227   -0.945041 -0.332647
# 173037      0.684876    -0.237227   -1.215431 -0.332647
#
# [173038 rows x 10 columns]

# %%
# Everything scaled in df except popularity column
master_scaled2 = copy.copy(master_df)


cols = master_scaled2.columns[master_scaled2.columns != 'popularity']
master_scaled2[cols] = scaler.fit_transform(master_scaled2[cols])
master_scaled2
# Out:
#            bpm    energy        dB  liveness  duration  acousticness  \
# 0    -1.172256 -1.025058 -1.526776  2.635600  4.792882      1.287754
# 1    -1.825041 -0.539354 -0.184395 -0.260684 -0.401646      0.623490
# 2    -0.214014 -1.193187 -0.606838 -0.599061  2.147449      1.231956
# 3    -0.547614 -0.658912  0.363604  1.006799 -0.166569      1.247898
# 4    -0.496873 -1.092310  0.226824  0.135046 -0.512057      1.221328
# ...        ...       ...       ...       ...       ...           ...
# 2380  0.753228  1.474450  0.945098 -0.604797 -0.022971     -0.816637
# 2381  1.079327  1.549174  1.295818  0.886359  0.080739     -1.321478
# 2382 -0.551168  1.437088  0.769738 -0.662149  0.192426     -1.321478
# 2383  0.101030  1.175555  0.945098 -0.776853 -0.413876     -1.321478
# 2384 -0.714218  0.577765  0.243658 -0.088627 -0.453765     -1.321478
#
#       danceability  speechiness  popularity   Streams
# 0        -1.475706    -0.381671           4 -0.332647
# 1         1.586536     1.954125           5 -0.332647
# 2        -1.197836    -0.398338           5 -0.332647
# 3        -1.498389    -0.389079           3 -0.332647
# 4        -0.687462    -0.373029           2 -0.332647
# ...            ...          ...         ...       ...
# 2380      0.344627    -0.360684          21 -0.332647
# 2381      0.061086    -0.052042          16 -0.332647
# 2382      0.344627    -0.298955          15 -0.332647
# 2383      0.628168    -0.237227          11 -0.332647
# 2384      0.684876    -0.237227           5 -0.332647
#
# [173038 rows x 10 columns]

# %% [markdown]
# ## Basic Data Exploration

# %%
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 173038 entries, 0 to 2384
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   bpm           173038 non-null  float64
#  1   energy        173038 non-null  float64
#  2   dB            173038 non-null  float64
#  3   liveness      173038 non-null  float64
#  4   duration      173038 non-null  float64
#  5   acousticness  173038 non-null  float64
#  6   danceability  173038 non-null  float64
#  7   speechiness   173038 non-null  float64
#  8   popularity    173038 non-null  int64
#  9   Streams       173038 non-null  int64
# dtypes: float64(8), int64(2)
# memory usage: 14.5 MB

# %%
# Most common genres with top hits on spotify
genre_counts = top100_2000["top genre"].value_counts()
ax = genre_counts.head(15).plot.barh(figsize = (10, 10))
ax.set_xlabel("Number of songs in top 100 since 2000")
ax.set_ylabel("Genre of Song")
ax.set_title("Number of top 100 hits vs. Genre of Song (since 2000)")
None

# %%
# Artists with more than 10 top 100 hits since 2000
art_top = top100_2000["artist"].value_counts()
art_more_10 = art_top[art_top > 10]
art_more_10.plot.bar(figsize = (8, 8))
# Out:
# <AxesSubplot:>

# %%
# Artists with one hit wonders since 2000
one_wonder = art_top[art_top == 1]
one_wonder_artists = list(one_wonder.index)
one_wonder_artists
# Out:
# ['DaFOO',
#  'Papa Roach',
#  'Elbow',
#  'Bubba Sparxxx',
#  'Busted',
#  'Khia',
#  'Truth Hurts',
#  'Judika',
#  'E-40',
#  'G-Unit',
#  'Stormzy',
#  'London',
#  'Shop Boyz',
#  'Stefflon Don',
#  'The Supermen Lovers',
#  'Simple Plan',
#  'BOYS LIKE GIRLS',
#  'Big Shaq',
#  'LMC',
#  'Dom Devino',
#  'PARTYNEXTDOOR',
#  'No Work On Monday',
#  'Fuel',
#  'BENEE',
#  'Special D.',
#  'Steve Aoki',
#  'Illy',
#  'Shania Twain',
#  'D4L',
#  'Eamon',
#  'Beach Blvd',
#  'Marta Delas',
#  'Fitz and The Tantrums',
#  'Death Cab for Cutie',
#  'Sonique',
#  'Thimo Konings',
#  'A.R. Rahman',
#  'Phoenix',
#  'Maithili Raelle',
#  'Matoma',
#  'Jordan Cabo Smith',
#  'Kodiro',
#  'Preston TO',
#  'Mary Mary',
#  'JUVENILE',
#  'Big Tymers',
#  'Filter',
#  'Rich Homie Quan',
#  'Kent Jones',
#  'Imany',
#  'Mando Diao',
#  'Dermot Kennedy',
#  'Take That',
#  'Yo Gotti',
#  'Agnes',
#  'Benny Benassi',
#  'Michael Franti & Spearhead',
#  'Everything Brighter',
#  'Bobby V.',
#  'Natalie La Rose',
#  'Sugarland',
#  'Blueface',
#  'KALEO',
#  'Baha Men',
#  'Philip George',
#  'Stevan Pasaribu',
#  'Cherish',
#  'Desire Machines',
#  'Rui Da Silva',
#  'G.R.L.',
#  'Silentó',
#  'Panjabi MC',
#  'Lumidee',
#  'NEIKED',
#  'Monica',
#  "Lil' Flip",
#  'The Roots',
#  'Cher Lloyd',
#  'Wale',
#  'DRAM',
#  'Starley',
#  'Molly Warburton',
#  'Lil Pump',
#  'INNA',
#  'Tyrese',
#  'The Band Perry',
#  'HÄWK',
#  'All Saints',
#  'Marlon Percy',
#  'Will Smith',
#  'Switchfoot',
#  'KJ Hand',
#  'Janelle Monáe',
#  'Yolanda Be Cool',
#  'Havens',
#  'Mila Nabours',
#  'KTEE',
#  'Marcello Spooks',
#  'Charli XCX',
#  'Sting',
#  'Ekat Bork',
#  'Thomas Rhett',
#  'The Chemical Brothers',
#  'EO',
#  'Ella Henderson',
#  'Charlie Mat',
#  'Lykke Li',
#  'Lukx',
#  'Hunter Mouallem',
#  'Wolfmother',
#  'Armand Van Helden',
#  'Emily Hearn',
#  'Chase & Status',
#  'Meck',
#  'Hoodie Forester',
#  '99 Souls',
#  'Youngbloodz',
#  'DJ Pied Piper & The Masters Of Ceremonies',
#  "Bomfunk MC's",
#  'Peking Duk',
#  'Matt Simons',
#  'Carl Thomas',
#  '3LW',
#  'Kandi',
#  'N.O.R.E.',
#  'NSG',
#  'DB Boulevard',
#  'Sidney Samson',
#  'N.E.R.D',
#  'Moloko',
#  'Da Brat',
#  'H "two" O',
#  'Girls Aloud',
#  'NSB',
#  'iio',
#  'Timeflies',
#  'Fedde Le Grand',
#  'Wayne Wonder',
#  'Young T & Bugsey',
#  'André Aires',
#  'Baby Boy Da Prince',
#  'Rich Boy',
#  'J-Kwon',
#  'Samantha Mumba',
#  'Next',
#  'Milow',
#  'Fatman Scoop',
#  'Sam Sparro',
#  'Jibbs',
#  'Danity Kane',
#  'Otto Knows',
#  'Anneth',
#  'Hayden James',
#  'Tim Berg',
#  'Faith Evans',
#  'Pendulum',
#  'CHVRCHES',
#  'Amanda Perez',
#  'Lucas & Steve',
#  'Chumbawamba',
#  'David Banner',
#  'Orson',
#  'Just Jack',
#  'Chip',
#  'Counting Crows',
#  'Duck Sauce',
#  'Big Brovaz',
#  'Amerie',
#  'David Bowie',
#  'M.O',
#  'AlunaGeorge',
#  'So Solid Crew',
#  'Jenil',
#  'Unk',
#  'Karley Scott Collins',
#  'Chicane',
#  'Mann',
#  'Jim Jones',
#  'Sammie',
#  'Lemar',
#  'Cashmere Cat',
#  'King Princess',
#  'Huey',
#  'Faithless',
#  'PNAU',
#  'M.O.P.',
#  'Howie Day',
#  'Kiiara',
#  'Olivia Holt',
#  'Sweet Female Attitude',
#  'Charli Baltimore',
#  'Tamia',
#  'Will Young',
#  'Sheryl Crow',
#  'Trillville',
#  'Sak Noel',
#  'Jaheim',
#  'Sweet Imperfections',
#  'O.T. Genasis',
#  'Trill Ryan',
#  'Gorgon City',
#  'Vengaboys',
#  'Default',
#  'Plan B',
#  "K'NAAN",
#  'Marc E. Bassy',
#  'Montell Jordan',
#  'Sunshine Anderson',
#  'Houston',
#  'Jennifer Hudson',
#  'Asher Roth',
#  'Radiohead',
#  'Room 5',
#  'Katie Melua',
#  'Lloyd Banks',
#  'Floetry',
#  'Angie Martinez',
#  'Professor Green',
#  'Maxwell',
#  'Ultrabeat',
#  'Tweet',
#  'The Prodigy',
#  'ZHU',
#  'Petey Pablo',
#  'T2',
#  'Project North',
#  'Nas',
#  'Bone Thugs-N-Harmony',
#  'Trick Daddy',
#  'Maeesha b',
#  'B Young',
#  'New Hope Club',
#  'Dem Franchize Boyz',
#  'Seether',
#  'Kameechi',
#  'Sophie Ellis-Bextor',
#  'Sigma',
#  'Hinder',
#  'Leah Justine',
#  'Gotye',
#  'Alex Clare',
#  'Tinchy Stryder',
#  'Madison Avenue',
#  'Missy Higgins',
#  'Elliott Yamin',
#  'Adam Lambert',
#  'George Michael',
#  'Erykah Badu',
#  'Danyka',
#  'Roger Sanchez',
#  'The Fratellis',
#  'The Coral',
#  'The Veronicas',
#  'The Temper Trap',
#  'Klingande',
#  'Zay Hilfigerrr',
#  'Liberty X',
#  'Dere',
#  'Storm Queen',
#  'Eiffel 65',
#  'Ruff Endz',
#  'MiMS',
#  'Hilltop Hoods',
#  'Player1',
#  'Gabriella Cilmi',
#  "Colby O'Donis",
#  'Blessing Offor',
#  'PSY',
#  'Elvis Presley',
#  'Michel Teló',
#  'Jidenna',
#  'Rizzle Kicks',
#  'CeeLo Green',
#  'Kate Nash',
#  'Infernal',
#  'DJ Ötzi',
#  'Naughty Boy',
#  'Case',
#  'K-Ci & JoJo',
#  'Erick Sermon',
#  'Melanie C',
#  'Simply Red',
#  'Mystikal',
#  'Mac Miller',
#  'Third Eye Blind',
#  'Masked Wolf',
#  'M.I.A.',
#  'Lil Peep',
#  'Robin Schulz',
#  'Muse',
#  'Kungs',
#  'Mr. Probz',
#  'Vanessa Carlton',
#  'Jet',
#  'Alice Deejay',
#  'Lunay',
#  'Topic',
#  'Rob $tone',
#  'All Time Low',
#  'Incubus',
#  'Macklemore',
#  'Jamie Miller',
#  'gnash',
#  'Modjo',
#  'Skillet',
#  'M83',
#  'THE ANXIETY',
#  'Rixton',
#  "Plain White T's",
#  'Dynoro',
#  'R. City',
#  'Corinne Bailey Rae',
#  'Majestic',
#  'SAINt JHN',
#  'GROUPLOVE',
#  't.A.T.u.',
#  'Nico & Vinz',
#  'Estelle',
#  'Nadin Amizah',
#  'Gnarls Barkley',
#  'Piso 21',
#  'Trevor Daniel',
#  'JP Saxe',
#  'Audioslave',
#  'Dave',
#  'Juicy Luicy',
#  'Oliver Tree',
#  'John Newman',
#  'Mustard',
#  'Alien Ant Farm',
#  'Surfaces',
#  'THE SCOTTS',
#  'Ozuna',
#  'Daniel Powter',
#  'U2',
#  'Lil Mosey',
#  'Alex Gaudino',
#  'Three Days Grace',
#  'Guru Josh Project',
#  'Alex & Sierra',
#  'Bebe Rexha',
#  'Bazzi',
#  'Finger Eleven',
#  'A$AP Ferg',
#  'AWOLNATION',
#  'Azealia Banks',
#  'Jawsh 685',
#  'Kehlani',
#  'Lou Bega',
#  'Dennis Lloyd',
#  'Cassie',
#  'MEDUZA',
#  'Arizona Zervas',
#  'MK',
#  'Nio Garcia',
#  'Thirty Seconds To Mars',
#  'Dominic Fike',
#  'Aqua',
#  'Loud Luxury',
#  'Tones And I',
#  'Norah Jones',
#  'benny blanco',
#  'A$AP Rocky',
#  'The Red Jumpsuit Apparatus',
#  'Alok',
#  'Surf Mesa',
#  'Russ',
#  'The Wanted',
#  'OMI',
#  'Dean Lewis',
#  'Central Cee',
#  'Elton John',
#  'JISOO',
#  'Joji',
#  'Alec Benjamin',
#  'Kate Bush',
#  'The White Stripes',
#  'Kali Uchis',
#  'Tame Impala',
#  'Cris Mj',
#  'Imanbek',
#  'Gesaffelstein',
#  'Paloma Faith',
#  'WALK THE MOON',
#  'Hozier',
#  'GAYLE',
#  'Evanescence',
#  'Ice Spice',
#  'Elley Duhé',
#  'Arcángel',
#  'Farruko',
#  'The Walters',
#  'PinkPantheress',
#  'Metro Boomin',
#  'David Kushner',
#  'Rema',
#  'd4vd',
#  'Bizarrap',
#  'Tom Odell',
#  'Coi Leray',
#  'RAYE',
#  'NewJeans',
#  'JVKE',
#  'Glass Animals',
#  'Manuel Turizo',
#  'Morgan Wallen',
#  'Sabrina Carpenter',
#  'Yandel',
#  'Conan Gray',
#  'Jaymes Young',
#  'Capital Cities',
#  'Amy Macdonald',
#  'CKay',
#  'Madison Beer',
#  'MAGIC!',
#  'Milky Chance',
#  'Spice Girls',
#  'Pop Smoke',
#  'Carrie Underwood',
#  'American Authors',
#  'Lil Tjay',
#  'Don Omar',
#  'Alan Walker',
#  'Of Monsters and Men',
#  'Playboi Carti',
#  'Sheck Wes',
#  'LISA',
#  'Axwell /\\ Ingrosso',
#  'Regard',
#  'Franz Ferdinand',
#  'Lil Tecca',
#  'NF',
#  'French Montana',
#  'Ava Max',
#  'girl in red',
#  'Lukas Graham',
#  'Carly Rae Jepsen',
#  'Powfu',
#  'Giveon',
#  'Tainy',
#  '24kGoldn',
#  'Jimmy Eat World',
#  'Hoobastank',
#  'Lil Uzi Vert',
#  'Lil Baby',
#  'Snow Patrol',
#  'MKTO',
#  'Calum Scott',
#  'BØRNS',
#  'Jason Mraz',
#  'Bon Jovi',
#  'Little Mix',
#  'Eric Church',
#  'Shouse',
#  'Afroman',
#  'Martin Jensen',
#  'The Raconteurs',
#  'Liam Payne',
#  'Petit Biscuit',
#  'SAYGRACE',
#  'Michael Jackson',
#  'Nine Days',
#  'Jon Bellion',
#  'September',
#  'Fountains Of Wayne',
#  'O-Zone',
#  'Oliver Heldens',
#  'Smash Mouth',
#  'Shontelle',
#  'Bad Meets Evil',
#  'Junior Senior',
#  'Ayo & Teo',
#  'Metro Station',
#  'Joel Adams',
#  'Asaf Avidan',
#  'Grimes',
#  'The Notorious B.I.G.',
#  'Kevin Lyttle',
#  'Kevin Gates',
#  'Duncan Laurence',
#  'Ramz',
#  'Diddy - Dirty Money',
#  'StarBoi3',
#  'Blu Cantrell',
#  'Ardhito Pramono',
#  'The Rasmus',
#  'Kaleb J',
#  'Sezairi',
#  'AJ Tracey',
#  'The Chicks',
#  'Flipp Dinero',
#  'Freya Ridings',
#  'Yeah Yeah Yeahs',
#  'Nina Sky',
#  'Travis',
#  'Lil Jon',
#  'Edward Maya',
#  'Misellia',
#  'Diskoria',
#  'FRENSHIP',
#  'Cheryl',
#  'MØ',
#  'Kasabian',
#  'Klaxons',
#  'DJ Sammy',
#  'Chad Kroeger',
#  'Kiesza',
#  'Purple Disco Machine',
#  'Staind',
#  'Yung Joc',
#  'Russ Millions',
#  'Kevin Rudolf',
#  'Jamiroquai',
#  'The Shapeshifters',
#  'Budi Doremi',
#  'YG',
#  'Larissa Lambert',
#  'Young Thug',
#  'Las Ketchup',
#  'Matchbox Twenty',
#  'Spiderbait',
#  'Jamie Foxx',
#  'Faith Hill',
#  'David Archuleta',
#  'Secondhand Serenade',
#  'Deorro',
#  'Lee Ann Womack',
#  'Terror Squad',
#  'Ida Corr',
#  'Mahalini',
#  'Foals',
#  'Sebastian Ingrosso',
#  'Tom Jones',
#  'Lasgo',
#  'Passion Pit',
#  'Cali Swag District',
#  'Armin van Buuren',
#  'Jamelia',
#  'Kid Ink',
#  'Crazy Town',
#  'Kardinal Offishall',
#  'dhruv',
#  'MIKA',
#  'Trapt',
#  'Internet Money',
#  'FINNEAS',
#  'Alexandra Stan',
#  'Route 94',
#  'MARINA',
#  'NLE Choppa',
#  'Dan + Shay',
#  'James TW',
#  'Vampire Weekend',
#  'blackbear',
#  'Phillip Phillips',
#  'Bobby Shmurda',
#  'Astrid S',
#  'Aminé',
#  'Colbie Caillat',
#  'Sech',
#  'Travie McCoy',
#  'The Calling',
#  'Paulo Londra',
#  'Felix Jaehn',
#  'Myke Towers',
#  'GANGGA',
#  'alt-J',
#  'Bella Poarch',
#  'Echosmith',
#  'Juanes',
#  'BlocBoy JB',
#  'Sara Bareilles',
#  'Lady A',
#  'Wheatus',
#  'Two Door Cinema Club',
#  'Jack Ü',
#  'Tinashe',
#  'Pink Sweat$',
#  'ROSÉ',
#  'Lyodra',
#  'JP Cooper',
#  'Weeekly',
#  'Crazy Frog',
#  'The Corrs',
#  'LeAnn Rimes',
#  'Lil Dicky',
#  'Bingo Players',
#  'Toni Braxton',
#  'The Darkness',
#  'Mario Winans',
#  'Icona Pop',
#  'Panic! At The Disco',
#  'Jay Rock',
#  'Good Charlotte',
#  'Tim McGraw',
#  'Normani',
#  'Bridgit Mendler',
#  'Chamillionaire',
#  'Shinedown',
#  'Lenny Kravitz',
#  'P.O.D.',
#  'Burak Yeter',
#  'Hot Chelle Rae',
#  'CJ',
#  'Sofía Reyes',
#  'The Vamps',
#  'Lonestar',
#  'Toby Keith',
#  'Skrillex',
#  'Young Money',
#  'Madcon',
#  'Pia Mia',
#  'FIFTY FIFTY',
#  'KYLE',
#  'Passenger',
#  'Rich The Kid',
#  'Darude',
#  'Alvaro Soler',
#  'Klangkarussell',
#  'Mike Perry',
#  'LEADR']

# %%
# Averages of multiple musical categories
means = master_df[["bpm", "energy", "dB", "liveness", "duration", "acousticness", "danceability", "speechiness", "popularity"]].mean()
means
# Out:
# bpm             116.901865
# energy           48.535959
# dB              -11.389475
# liveness         20.545316
# duration        230.879374
# acousticness     49.734602
# danceability     53.922803
# speechiness       9.843090
# popularity       31.970642
# dtype: float64

# %%
# Looking at the distributions of all the numerical variables
distributions = master_df.select_dtypes(include = ['int64', "float64"])
ax = distributions.hist(figsize=(10, 10), bins=30, xlabelsize=6, ylabelsize=8, color = "green")

# %%
# Building a dictionary with each genre having its corresponding data (since 2000 only)
all_genres = list(top100_2000["top genre"].value_counts().index)
genre_dfs = dict()
for genre in all_genres:
    genre_dfs[genre] = top100_2000[top100_2000["top genre"] == genre]

# %%
# For example, this is all the dance pop songs (since 2000 only)
genre_dfs["dance pop"]
# Out:
#                                                   title         artist  \
# 59                                  When I Was Your Man     Bruno Mars
# 65                                 Locked out of Heaven     Bruno Mars
# 69                             One Kiss (with Dua Lipa)  Calvin Harris
# 99                                                Woman       Doja Cat
# 136                                  That's What I Like     Bruno Mars
# ...                                                 ...            ...
# 2328                      Turnin Me On - Original Dirty    Keri Hilson
# 2329                               With Every Heartbeat          Robyn
# 2332                                           Loverboy   Mariah Carey
# 2354  Bounce With Me (feat. Xscape) - Edited Album V...        Bow Wow
# 2365                                         Rainy Dayz  Mary J. Blige
#
#       top genre  year  bpm  energy  danceability  dB  liveness  valence  \
# 59    dance pop  2012   73      28            61  -9         9       39
# 65    dance pop  2012  144      70            73  -4        31       87
# 69    dance pop  2018  124      86            79  -3         8       59
# 99    dance pop  2021  108      76            82  -4        12       88
# 136   dance pop  2016  134      56            85  -5         9       86
# ...         ...   ...  ...     ...           ...  ..       ...      ...
# 2328  dance pop  2008  160      58            66  -5        13        9
# 2329  dance pop  2005  121      88            50  -4        23       41
# 2332  dance pop  2001  103      79            72  -4        10       82
# 2354  dance pop  2000   72      75            85  -5        27       93
# 2365  dance pop  2001   69      67            41  -7        31       53
#
#       duration  acousticness  speechiness  popularity      Streams
# 59         214            93            4          89  18201285113
# 65         233             5            4          88  18201285113
# 69         215             4           11          88  17820311936
# 99         173             9            9          87  11973361879
# 136        207             1            4          86  18201285113
# ...        ...           ...          ...         ...          ...
# 2328       248             0            6          43            0
# 2329       253             1            4          43            0
# 2332       229            18           12          42   5888465193
# 2354       176            43           17          36            0
# 2365       276            20           23          31   1603823302
#
# [460 rows x 15 columns]

# %%
# Trying to see which parts of top 100 songs are above/below average
genre_counts = top100_2000["top genre"].value_counts()
popular_genres = list(genre_counts[genre_counts > 50].index)
genres_stats = dict()
for genre in popular_genres:
    current_df = genre_dfs[genre]
    cur_bpm = round(current_df["bpm"].mean(), 2)
    cur_energy = round(current_df["energy"].mean(), 2)
    cur_duration = round(current_df["duration"].mean(), 2)
    cur_popularity = round(current_df["popularity"].mean(), 2)
    cur_df_list = [cur_bpm, cur_energy, cur_duration, cur_popularity]
    genres_stats[genre] = cur_df_list
genres_stats_df = pd.DataFrame(genres_stats, index = ["bpm", "energy", "duration", "popularity"])

ax = genres_stats_df.plot.bar(figsize = (12, 12))
ax.axhline(y = means["bpm"], linestyle = "--", color = "black")
ax.axhline(y = means["energy"], linestyle = "--", color = "black")
ax.axhline(y = means["duration"], linestyle = "--", color = "black")
ax.axhline(y = means["popularity"], linestyle = "--", color = "black")
ax.set_title("Genres with over 50 songs in the top 100 averages")
# Out:
# Text(0.5, 1.0, 'Genres with over 50 songs in the top 100 averages')

# %%
plt.figure(figsize=(16, 6))
plot = sns.heatmap(master_df.corr(), annot = True)
plot.set_title("Correlations Between Variables")
None
# Appears that variables that have strongest correlation with popularity is bpm, energy, dB, acousticness, danceability, speechiness, and streams

# %% [markdown]
# ## Part 2: Building Models

# %% [markdown]
# ### Linear Regression

# %%
# Basic ML model to predict popularity of a given pop song based on bpm, energy, speechiness, duration
xcols1 = ["bpm", "energy", "dB", "acousticness", "danceability", "speechiness", "Streams"]
ycols1 = "popularity"

pop_df = genre_dfs["pop"]
train, test = train_test_split(master_scaled2)
model1 = LinearRegression()
model1.fit(train[xcols1], train[ycols1])
model1score = model1.score(test[xcols1], test[ycols1])

print(f"Model 1 Score: {model1score}")
# Out:
# Model 1 Score: 0.4426115976183511

# %%
model2 = Pipeline([
    ("pf", PolynomialFeatures(degree=3, include_bias=False)),
    ("lr", LinearRegression())
])
model2.fit(train[xcols1], train[ycols1])
m2score = model2.score(test[xcols1], test[ycols1])

print(f"Model 2 Score: {m2score}")
# Out:
# Model 2 Score: 0.5590298416536976

# %% [markdown]
# ### Logistic Regression

# %%
new_spotify = copy.copy(master_scaled2)
new_spotify["logistic_rating"] = new_spotify["popularity"].apply(lambda x : x // 10)
new_spotify.head()
# Out:
#         bpm    energy        dB  liveness  duration  acousticness  \
# 0 -1.172256 -1.025058 -1.526776  2.635600  4.792882      1.287754
# 1 -1.825041 -0.539354 -0.184395 -0.260684 -0.401646      0.623490
# 2 -0.214014 -1.193187 -0.606838 -0.599061  2.147449      1.231956
# 3 -0.547614 -0.658912  0.363604  1.006799 -0.166569      1.247898
# 4 -0.496873 -1.092310  0.226824  0.135046 -0.512057      1.221328
#
#    danceability  speechiness  popularity   Streams  logistic_rating
# 0     -1.475706    -0.381671           4 -0.332647                0
# 1      1.586536     1.954125           5 -0.332647                0
# 2     -1.197836    -0.398338           5 -0.332647                0
# 3     -1.498389    -0.389079           3 -0.332647                0
# 4     -0.687462    -0.373029           2 -0.332647                0

# %%
# Logistic Regression model to predict how popular a song will be based on bpm, energy, valence, acousticness, liveness, and duration
train, test = train_test_split(new_spotify)
xcols2 = ["bpm", "energy", "dB", "acousticness", "danceability", "speechiness", "Streams"]
ycols2 = "logistic_rating"
model3 = Pipeline([
#     ("std", StandardScaler()),
    ("lr", LogisticRegression(fit_intercept=False, max_iter=100))
])

model3.fit(train[xcols2], train[ycols2])
model3_score = model3.score(test[xcols2], test[ycols2])
model3_cross = cross_val_score(model3, train[xcols2], train[ycols2]).mean()
print(f"10 tiered logistic score: {model3_score}")
print(f"10 tiered logistic cros val: {model3_cross}")
# Out:
# 10 tiered logistic score: 0.3638002773925104
# 10 tiered logistic cros val: 0.36768944875638127

# %%
# Adding 3 tiered column to use for this logistic regression
spotify_3_tier = copy.copy(master_scaled2)
spotify_3_tier["popularity3tier"] = spotify_3_tier["popularity"].apply(lambda x: x // 33)
spotify_3_tier.head()
# Out:
#         bpm    energy        dB  liveness  duration  acousticness  \
# 0 -1.172256 -1.025058 -1.526776  2.635600  4.792882      1.287754
# 1 -1.825041 -0.539354 -0.184395 -0.260684 -0.401646      0.623490
# 2 -0.214014 -1.193187 -0.606838 -0.599061  2.147449      1.231956
# 3 -0.547614 -0.658912  0.363604  1.006799 -0.166569      1.247898
# 4 -0.496873 -1.092310  0.226824  0.135046 -0.512057      1.221328
#
#    danceability  speechiness  popularity   Streams  popularity3tier
# 0     -1.475706    -0.381671           4 -0.332647                0
# 1      1.586536     1.954125           5 -0.332647                0
# 2     -1.197836    -0.398338           5 -0.332647                0
# 3     -1.498389    -0.389079           3 -0.332647                0
# 4     -0.687462    -0.373029           2 -0.332647                0

# %%
# Logistic regression model attempting to predict 3 tier popularity
train, test = train_test_split(spotify_3_tier)
xcols_3tier = ["bpm", "energy", "dB", "liveness", "duration", "acousticness", "Streams", "danceability"]
ycol_3tier = "popularity3tier"

model3tier = LogisticRegression(fit_intercept=False, max_iter=100)

model3tier.fit(train[xcols_3tier], train[ycol_3tier])
score = model3tier.score(test[xcols_3tier], test[ycol_3tier])
cval = cross_val_score(model3tier, test[xcols_3tier], test[ycol_3tier]).mean()
print(f"3 tier Logistic Score Compared to Real Numbers: {score}")
print(f"3 tier Logistic CV Score: {cval}")
None


# 68% accuracy on categorizing songs into 3 categories of poularity, that is pretty good.
# Out:
# 3 tier Logistic Score Compared to Real Numbers: 0.6777392510402219
# 3 tier Logistic CV Score: 0.6800046232085066

# %%
# 2 tiered regression
copy_2_tier = copy.copy(master_scaled2)
copy_2_tier["tier2"] = copy_2_tier["popularity"].apply(lambda x : x // 50)

train, test = train_test_split(copy_2_tier)
model_2_tier = LogisticRegression(fit_intercept=False, max_iter=100)

x_predictors = ["bpm", "energy", "dB", "liveness", "duration", "acousticness", "Streams", "danceability"]
y_predictor = "tier2"

model_2_tier.fit(train[x_predictors], train[y_predictor])
model_2_tier_score = model_2_tier.score(test[x_predictors], test[y_predictor])
model_2_tier_CV = cross_val_score(model_2_tier, test[x_predictors], test[y_predictor]).mean()
print(f"model_2tier_score : {model_2_tier_score}")
print(f"model_2tier_CV : {model_2_tier_CV}")

# Almsot 75% accuracy on predicting if a song will be poular or not, pretty good.
# Out:
# model_2tier_score : 0.7305594082293111
# model_2tier_CV : 0.7419556171983357

# %% [markdown]
# ## Decision Trees

# %%
# Decision Tree predicting popularity straight up
y = master_scaled2.popularity
features = ["bpm", "energy", "dB", "liveness", "duration", "acousticness", "Streams"]
X = master_scaled2[features]

train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=1)
spotify_tree_model = DecisionTreeRegressor(random_state=1)
spotify_tree_model.fit(train_X, train_y)
val_predictions = spotify_tree_model.predict(val_X)
val_mae = mean_absolute_error(val_predictions, val_y)
print("MAE:", val_mae)
# Looks like this model is off by almost 15 on average for popularity of the song.
# Out:
# MAE: 14.619693987627413

# %%
# Decision tree classification trying to classify into either 0, 1, or 2
y = spotify_3_tier.popularity3tier
features = ["bpm", "energy", "dB", "liveness", "speechiness", "danceability", "Streams"]
X = spotify_3_tier[features]
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=1)
tiered = DecisionTreeClassifier(criterion="entropy", max_depth=3)
tiered.fit(train_X, train_y)
val_predictions = tiered.predict(val_X)
val_mae = mean_absolute_error(val_predictions, val_y)
print(f"MAE: {val_mae}")
accuracy = accuracy_score(val_predictions, val_y)
print(f"ACCURACY: {accuracy}")
# Out:
# MAE: 0.342417938049006
# ACCURACY: 0.6634073046694406

# %%
# Making data all scaled on a 10 scale for simplicity to the model (besides popularity, keeping that 3 tiered)
master_df_scaled10 = copy.copy(master_df)
for val in ["bpm", "energy", "dB", "liveness", "duration", "acousticness", "danceability", "speechiness", "Streams"]:
    master_df_scaled10[val] = master_df_scaled10[val].apply(lambda x: x // 10)
    
master_df_scaled10["popularity"] = master_df_scaled10["popularity"].apply(lambda x: x // 33)
master_df_scaled10
# Out:
#        bpm  energy   dB  liveness  duration  acousticness  danceability  \
# 0      8.0     2.0 -3.0       6.0      83.0           9.0           2.0
# 1      6.0     3.0 -2.0       1.0      18.0           7.0           8.0
# 2     11.0     1.0 -2.0       1.0      50.0           9.0           3.0
# 3     10.0     3.0 -1.0       3.0      21.0           9.0           2.0
# 4     10.0     1.0 -2.0       2.0      16.0           9.0           4.0
# ...    ...     ...  ...       ...       ...           ...           ...
# 2380  14.0     8.0 -1.0       1.0      22.0           1.0           6.0
# 2381  15.0     9.0 -1.0       3.0      24.0           0.0           5.0
# 2382  10.0     8.0 -1.0       0.0      25.0           0.0           6.0
# 2383  12.0     8.0 -1.0       0.0      17.0           0.0           6.0
# 2384   9.0     6.0 -1.0       1.0      17.0           0.0           6.0
#
#       speechiness  popularity  Streams
# 0             0.0           0        0
# 1             4.0           0        0
# 2             0.0           0        0
# 3             0.0           0        0
# 4             0.0           0        0
# ...           ...         ...      ...
# 2380          0.0           0        0
# 2381          0.0           0        0
# 2382          0.0           0        0
# 2383          0.0           0        0
# 2384          0.0           0        0
#
# [173038 rows x 10 columns]

# %%
# This is a decision tree regressor that tries to predict popularity rating 0, 1, or 2. 
y = master_df_scaled10.popularity
features = ["dB", "speechiness",   "acousticness", "Streams"]
X = master_df_scaled10[features]
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=1)
spotify_tree_model = DecisionTreeRegressor(random_state=1)
spotify_tree_model.fit(train_X, train_y)
val_predictions = spotify_tree_model.predict(val_X)
val_mae = mean_absolute_error(val_predictions, val_y)

print("MAE:", val_mae)
# Out:
# MAE: 0.35468840261415885

# %%
# Best model so far to predict the 3 tiers of popularity. 
y = master_df_scaled10.popularity
features = ["energy", "duration", "Streams"]
X = master_df_scaled10[features]
train_X, val_X, train_y, val_y = train_test_split(X, y, random_state=1)
tiered = DecisionTreeClassifier()
tiered.fit(train_X, train_y)

val_predictions = tiered.predict(val_X)
val_mae = mean_absolute_error(val_predictions, val_y)
print(f"MAE: {val_mae}")
accuracy = accuracy_score(val_predictions, val_y)
print(f"ACCURACY: {accuracy}")
# Out:
# MAE: 0.3179380490060102
# ACCURACY: 0.6916319926028663

# %% [markdown]
# ## Neural Networks

# %%
spotify_3_tier
# Out:
#            bpm    energy        dB  liveness  duration  acousticness  \
# 0    -1.172256 -1.025058 -1.526776  2.635600  4.792882      1.287754
# 1    -1.825041 -0.539354 -0.184395 -0.260684 -0.401646      0.623490
# 2    -0.214014 -1.193187 -0.606838 -0.599061  2.147449      1.231956
# 3    -0.547614 -0.658912  0.363604  1.006799 -0.166569      1.247898
# 4    -0.496873 -1.092310  0.226824  0.135046 -0.512057      1.221328
# ...        ...       ...       ...       ...       ...           ...
# 2380  0.753228  1.474450  0.945098 -0.604797 -0.022971     -0.816637
# 2381  1.079327  1.549174  1.295818  0.886359  0.080739     -1.321478
# 2382 -0.551168  1.437088  0.769738 -0.662149  0.192426     -1.321478
# 2383  0.101030  1.175555  0.945098 -0.776853 -0.413876     -1.321478
# 2384 -0.714218  0.577765  0.243658 -0.088627 -0.453765     -1.321478
#
#       danceability  speechiness  popularity   Streams  popularity3tier
# 0        -1.475706    -0.381671           4 -0.332647                0
# 1         1.586536     1.954125           5 -0.332647                0
# 2        -1.197836    -0.398338           5 -0.332647                0
# 3        -1.498389    -0.389079           3 -0.332647                0
# 4        -0.687462    -0.373029           2 -0.332647                0
# ...            ...          ...         ...       ...              ...
# 2380      0.344627    -0.360684          21 -0.332647                0
# 2381      0.061086    -0.052042          16 -0.332647                0
# 2382      0.344627    -0.298955          15 -0.332647                0
# 2383      0.628168    -0.237227          11 -0.332647                0
# 2384      0.684876    -0.237227           5 -0.332647                0
#
# [173038 rows x 11 columns]

# %%
# train, test = train_test_split(spotify_3_tier)

# features = train[["energy", "duration", "Streams"]].values
# labels = train["popularity3tier"].values

# model = Sequential()
# model.add(LSTM)
# model.add(Dense(32, activation='relu'))
# model.add(Dense(3, activation='softmax'))

# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# model.fit(features, labels, batch_size=32, epochs=10, validation_split=0.2)

# #prediction
# new_songs_features = test[['loudness', 'danceability', 'duration']].values
# predictions = model.predict(new_songs_features)
# print(predictions)

# %% [markdown]
# ## Clustering

# %%
X = master_scaled[["bpm", "energy", "dB", "liveness", "duration", "speechiness", "danceability", "acousticness"]]
sse = []
for k in range(1, 12):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(X)
    sse.append(kmeans.inertia_)
    
cluster_df = pd.DataFrame({'Cluster':range(1,12), 'sse':sse})
cluster_df.head()

plt.figure(figsize=(12,6))
plt.plot(cluster_df['Cluster'], cluster_df['sse'])
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')

# %%
model =  Pipeline([
    ("std", StandardScaler()),
    ("km", KMeans(6)),
])
clusters = model.fit_predict(X)
clusters

PCA_df = copy.copy(master_scaled)

pca = PCA(n_components=2)  
df_2d = pca.fit_transform(master_scaled)
plt.scatter(df_2d[:, 0], df_2d[:, 1], c=clusters)
plt.title("6 clusters KMeans")
plt.figure(figsize = (25, 25))
plt.show()

# %% [markdown]
# ###

# %%
# Other kinds of clustering
